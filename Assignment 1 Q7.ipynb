# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv(r'D:\DATA Science\Q7.csv')
df.head(5)
# Out:
#           Unnamed: 0  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %%
df.rename( columns={'Unnamed: 0':'Cars'}, inplace=True )

# %%
df1= df.drop(['Cars'],axis=1)
df1.head(5)
# Out:
#    Points  Score  Weigh
# 0    3.90  2.620  16.46
# 1    3.90  2.875  17.02
# 2    3.85  2.320  18.61
# 3    3.08  3.215  19.44
# 4    3.15  3.440  17.02

# %%
df1.mean()
# Out:
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
df1.median()
# Out:
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
df1.mode()
# Out:
#    Points  Score  Weigh
# 0    3.07   3.44  17.02
# 1    3.92    NaN  18.90

# %%
df1['Points'].mode()
# Out:
# 0    3.07
# 1    3.92
# Name: Points, dtype: float64

# %%
df1['Score'].mode()
# Out:
# 0    3.44
# Name: Score, dtype: float64

# %%
df1['Weigh'].mode()
# Out:
# 0    17.02
# 1    18.90
# Name: Weigh, dtype: float64

# %%
df1.std()
# Out:
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64

# %%
df1.var()
# Out:
# Points    0.285881
# Score     0.957379
# Weigh     3.193166
# dtype: float64

# %%
"Range for Points is" , df1['Points'].max() - df1['Points'].min()
# Out:
# ('Range for Points is', 2.17)

# %%
"Range for Score is" , df1['Score'].max() - df1['Score'].min()
# Out:
# ('Range for Score is', 3.9110000000000005)

# %%
import matplotlib.pyplot as plt
plt.hist(df["Points"], bins = 10, edgecolor= 'black')
plt.show()

# %%
plt.boxplot(x = 'Points', data =df)
plt.xlabel('Points')
plt.ylabel('Density')
plt.savefig("PointsInferences.png")
plt.show()

# %%
plt.hist(df["Score"], bins = 20, edgecolor = 'y')
plt.show()

# %%
plt.boxplot(x = 'Score', data= df)
plt.xlabel('Scores')
plt.ylabel('Density')
plt.savefig("ScoresInferences.png")
plt.show()

# %%
plt.hist(df["Weigh"], bins=20, edgecolor = 'red')
plt.show()

# %%
plt.boxplot(x= "Weigh", data = df)
plt.xlabel('Weigh')
plt.ylabel('Density')
plt.savefig("WeighInferences.png")
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.barh(df["Cars"], df["Points"])
plt.yticks(fontsize=14)
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.barh(df["Cars"], df["Score"])
plt.yticks(fontsize=14)
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.barh(df["Cars"], df["Weigh"])
plt.yticks(fontsize=14)
plt.show()
