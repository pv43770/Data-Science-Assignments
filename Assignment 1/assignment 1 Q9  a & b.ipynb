# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv(r'D:\DATA Science\Q9_a.csv')
df.head(5)
# Out:
#    Index  speed  dist
# 0      1      4     2
# 1      2      4    10
# 2      3      7     4
# 3      4      7    22
# 4      5      8    16

# %%
df.skew()
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
df.kurtosis()
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
#Q. draw interface of Speed and Distance
import matplotlib.pyplot as plt
x_data = df['speed']
y_data = df['dist']
plt.plot(x_data,y_data)
plt.show()

# %%
df_b= pd.read_csv(r'D:\DATA Science\Q9_b.csv')
df_b.head(5)
# Out:
#    Unnamed: 0          SP         WT
# 0           1  104.185353  28.762059
# 1           2  105.461264  30.466833
# 2           3  105.461264  30.193597
# 3           4  113.461264  30.632114
# 4           5  104.461264  29.889149

# %%
#Q. draw interface of SP and WT
plt.plot(df_b['SP'],df_b['WT'])
plt.show()
